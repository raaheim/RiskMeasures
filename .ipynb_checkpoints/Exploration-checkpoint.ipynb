# %%
import pandas as pd
import numpy as np

# %%
dfOBXIntra=pd.read_excel("OBXIntra.xlsx")

# %%
dfOBXIntra["Change"].hist(bins = 175).plot()
# Out:
# []

# %%
import scipy.stats
scipy.stats.normaltest(dfOBXIntra["Change"])
# Out:
# NormaltestResult(statistic=31094.816844580964, pvalue=0.0)

# %%
dfOBXIntra["Change"].plot()

# %%
dfOBXlast=pd.read_excel("OBXlast.xlsx")
dfOBXlast.dropna()

fig, axes = plt.subplots(figsize=(12,4))
dfOBXlast["Change"].hist(bins = 175).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f14657014250> in <module>()
#       2 dfOBXlast.dropna()
#       3
# ----> 4 fig, axes = plt.subplots(figsize=(12,4))
#       5 dfOBXlast["Change"].hist(bins = 175).plot()
#
# NameError: name 'plt' is not defined

# %%
scipy.stats.normaltest(dfOBXlast["Change"].dropna())
# Out:
# NormaltestResult(statistic=883.2178718734868, pvalue=1.6280808330744061e-192)

# %%
import numpy as np 
import pylab 
import scipy.stats as stats

stats.probplot(dfOBXlast["Change"].dropna(), dist="norm", plot=pylab)
pylab.show()

# %%
dfOBXlast.plot("OBX","Change")

# %%
dfSnP500=pd.read_csv("SnP500.csv")

# %%
dfSnP500
# Out:
#             Date         Open         High          Low        Close  \
# 0     1990-01-02   353.399994   359.690002   351.980011   359.690002
# 1     1990-01-03   359.690002   360.589996   357.890015   358.760010
# 2     1990-01-04   358.760010   358.760010   352.890015   355.670013
# 3     1990-01-05   355.670013   355.670013   351.350006   352.200012
# 4     1990-01-08   352.200012   354.239990   350.540009   353.790009
# 5     1990-01-09   353.829987   354.170013   349.609985   349.619995
# 6     1990-01-10   349.619995   349.619995   344.320007   347.309998
# 7     1990-01-11   347.309998   350.140015   347.309998   348.529999
# 8     1990-01-12   348.529999   348.529999   339.489990   339.929993
# 9     1990-01-15   339.929993   339.940002   336.570007   337.000000
# 10    1990-01-16   337.000000   340.750000   333.369995   340.750000
# 11    1990-01-17   340.769989   342.010010   336.260010   337.399994
# 12    1990-01-18   337.399994   338.380005   333.980011   338.190002
# ...

# %%
dfSnP500 = dfSnP500.assign(Change = (dfSnP500["Close"][1:] - dfSnP500["Close"][:-1])/dfSnP500["Close"][:-1])

# %%
dfSnP500.plot("Date","Change")
