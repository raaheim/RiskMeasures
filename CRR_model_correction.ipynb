# %% [markdown]
# The aim of this Notebook is to create a code that calculate simulations for the pricicng and hedging of derivatives defined by a Cox-Ross-Rubinstien (CRR) model

# %% [markdown]
# ### Parameters of the model

# %% [markdown]
# The parameters of the models are the following:

# %%
import os
import numpy as np
import scipy as scp
import pylab
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx 
r = 0.05  # The interest rate of the riskless bond
p = 0.5   # The probability for the price at each period to go upwarwd
q = 1.0-p # The probability for the price at each period to go downwarwd
u = 2.0   # The level of increase of the price
d = 0.5   # The level of decrease of the price
T = 50     # Number of periods in the model
S0 = 100  # Value of the risky asset at time 0

# %% [markdown]
# ### The non-arbitrage condition

# %% [markdown]
# ##### 1) Recall the non-arbitrage conditon and create a test command which prints an error message in case in is not satisfied

# %% [markdown]
# The non-arbitrage condition is:
# $d < 1+r < u$. Write a code below which tests the non-arbitrage condition and define the $p^\ast$

# %%
if (d < 1+r) & (u>1+r) :
    print("Marché viable")
else :
    print("Arbitrage")

p_star = (1.0+r-d)/(u-d)
print("p*=",p_star)
# Out:
# Marché viable
# p*= 0.3666666666666667

# %% [markdown]
# ### Simulating sample paths of the risky asset

# %%
M = 100000000   # The number of simulated sample paths
S = np.zeros((M,T+1))

# %% [markdown]
# We create and initialize the first valuer of the stock $S$

# %%
start = np.zeros(M)
for i in range(0,M):
    start[i]=S0
S[:,0]=start

# %% [markdown]
# ##### 2) Simulate $M$ paths of the stock $S$

# %%
B = np.random.binomial(1,p,T+1) # We simulate all the Bernouilli random variables

# %%
def transform(B): # Transform a vector of O and 1 into a vector of u and d's
    temp1 = np.size(B)
    up_and_down = np.zeros(temp1)
    for i in range(0,temp1):
        if B[i]==1:
            up_and_down[i]=u
        else:
            up_and_down[i]=d
    return up_and_down

# %%
def simulateS(m):
    B = np.zeros(m)
    up_and_down = np.zeros(m)
    for i in range(1,T+1):
        B = np.random.binomial(1,p,m)
        up_and_down = transform(B)
        S[:,i]=S[:,i-1]*up_and_down

# %%
simulateS(M)

# %%
t1=np.linspace(0,T,num=T+1)
plt.plot(np.transpose(S))
plt.grid()
plt.show()

# %% [markdown]
# ### Another representation using graphs (Binary trees)

# %%
def binomial_grid(n,s0):
    G=nx.Graph() 
    for i in range(0,n):
        j=-i+1
        while (j<i+2):
            G.add_edge((i,j),(i+1,j+1),weight=0.0)
            G.add_edge((i,j),(i+1,j-1),weight=0.0)
            j=j+2
    
    j=1
    for i in range(0,n):
        r=np.random.binomial(1,p,1)
        if r >0:
            G.add_edge((i,j),(i+1,j+1),weight=1.0)
            j=j+1
        else:
            G.add_edge((i,j),(i+1,j-1),weight=1.0)
            j=j-1
    
    posG={}
    lab={}
    for node in G.nodes():
        posG[node]=(node[0],node[1])
        if node[0]==0:
            lab[node]=s0
        i=node[0]
        j=node[1]
        if j>1:
            lab[node]=s0*(u**(j-1))
        elif j==1:
            lab[node]=s0
        else:
            lab[node]=s0*(d**(1-j))
    elarge=[(a,b) for (a,b,c) in G.edges(data=True) if c['weight'] >0.5]
    esmall=[(a,b) for (a,b,c) in G.edges(data=True) if c['weight'] <=0.5]
    fig, ax = plt.subplots(1,1,figsize = (12,8))
    nx.draw_networkx_edges(G,posG,edge_color='blue',width=1)
    nx.draw_networkx_labels(G,posG,lab,font_size=15,font_family='sans-serif')
    plt.xlim(-1, n+1)
    plt.ylim(-n-1, n+2)
    plt.yticks([], [])
    plt.xlabel("time", size = 20)
    plt.legend(["Value of risky asset"], loc = 2, fontsize = 12)
    plt.show()

# %%
binomial_grid(8,100.0)

# %% [markdown]
# ### Pricing

# %% [markdown]
# ##### Pricing of European Financial claims on the Cox-Ross-Rubinstien model

# %% [markdown]
# The aim of this section is to write a function "Price" which computes the (arbitrage) price at any time of a contract whose payoff is given by a mapping $g_T$ using the Dynamic Programming Principle as in Theorem 6.2.1.

# %% [markdown]
# we start with a plotting function for a Binary tree

# %%
def plot_tree(g):
    pos={}
    lab={}
    
    for n in g.nodes():
        pos[n]=(n[0],n[1])
        lab[n]=float(int(g.node[n]['value']*1000))/1000 # This is just to print only with 10^-2 precision
    
    elarge=g.edges(data=True)
    nx.draw_networkx_edges(g,pos,edgelist=elarge)
    nx.draw_networkx_labels(g,pos,lab,font_size=15,font_family='sans-serif')
    plt.xlim(-1, T+1)
    plt.ylim(-T-1, T+2)
    plt.show()

# %% [markdown]
# We construct the graph of prices

# %%
def graph_stock():
    S=nx.Graph()
    for i in range(0,T):
        j=-i+1
        while (j<i+2):
            S.add_edge((i,j),(i+1,j+1))
            S.add_edge((i,j),(i+1,j-1))
            j=j+2
            
    for n in S.nodes():
        
        if n[0]==0:
            S.node[n]['value']=S0
        i=n[0]
        j=n[1]
        if j>1:
            S.node[n]['value'] = S0*(u**(j-1))
        elif j==1:
            S.node[n]['value'] = S0
        else:
            S.node[n]['value'] = S0*(d**(1-j))
    return S

# %%
S=nx.Graph()
S =graph_stock()
plot_tree(S)

# %% [markdown]
# ##### 3) Compute the price of a European Call Option

# %%
def European_call(x,K):
        return np.maximum(x-K,0.0)

# %%
def compute_European_Call_prices(K):

    g = nx.Graph()
    price = nx.Graph()
    
    S = nx.Graph()
    
    S = graph_stock()

    for i in range(0,T):
            j=-i+1
            while (j<i+2):
                g.add_edge((i,j),(i+1,j+1))
                g.add_edge((i,j),(i+1,j-1))
                price.add_edge((i,j),(i+1,j+1))
                price.add_edge((i,j),(i+1,j-1))
                j=j+2

    for n in S.nodes():
        if n[0]==T:
            g.node[n]['value'] = European_call(S.node[n]['value'],K)
            price.node[n]['value'] = European_call(S.node[n]['value'],K)
    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            g.node[(i,j)]['value'] = g.node[(i+1,j+1)]['value']*p_star + g.node[(i+1,j-1)]['value']*(1.0-p_star)
            price.node[(i,j)]['value'] = g.node[(i,j)]['value']*((1.0+r)**(i-T))
            j=j+2
        i=i-1
        
    return price

# %% [markdown]
# Computation the price of a European Call option

# %%
price = nx.Graph()
S = nx.Graph()
S = graph_stock()

K=0.0

K = input("Enter the value of the strike K : ")

price_Call = compute_European_Call_prices(float(K))

plot_tree(S)
plot_tree(price_Call)

print('Value of the price at time 0 of the European Call option with strike ',K,' = ',price_Call.node[(0,1)]['value'])
# Out:
# Enter the value of the strike K : 150
# Value of the price at time 0 of the European Call option with strike  150  =  52.735915428700615

# %% [markdown]
# ##### 4) Compute the price of a European Put Option

# %%
def compute_European_Put_prices(K):

    Put = nx.Graph()
    
    S = nx.Graph()
    S = graph_stock()
    
    Call = nx.Graph()
    Call = compute_European_Call_prices(K)

    for i in range(0,T):
            j=-i+1
            while (j<i+2):
                Put.add_edge((i,j),(i+1,j+1))
                Put.add_edge((i,j),(i+1,j-1))
                j=j+2
    
    for n in S.nodes():
        if n[0]==T:
            Put.node[n]['value'] = European_call(K,S.node[n]['value'])    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            Put.node[(i,j)]['value'] = Call.node[(i,j)]['value'] + K*(1.0+r)**(i-T) - S.node[(i,j)]['value']
            j=j+2
        i=i-1
        
    return Put

# %%
S = nx.Graph()
S = graph_stock()

price_Put = nx.Graph()
price_Call =nx.Graph()

K=0.0

K = input("Enter the value of the strike K : ")

price_Call = compute_European_Call_prices(float(K))

price_Put = compute_European_Put_prices(float(K))

plot_tree(S)
plot_tree(price_Call)
plot_tree(price_Put)
# Out:
# Enter the value of the strike K : 150

# %% [markdown]
# ##### 5) Complete the codes above to compute a hedging strategy and simumate the associated wealth processes

# %%
def compute_European_Call_strategy(K):

    Call = nx.Graph()
    Call = compute_European_Call_prices(float(K))

    S = nx.Graph()
    S = graph_stock()
    
    Strat_Call = nx.Graph()
    
    for i in range(0,T):
            j=-i+1
            while (j<i+2):
                Strat_Call.add_edge((i,j),(i+1,j+1))
                Strat_Call.add_edge((i,j),(i+1,j-1))
                j=j+2
    
    for n in S.nodes():
        if n[0]==T:
            Strat_Call.node[n]['value'] = 0.0    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            Strat_Call.node[(i,j)]['value'] = (Call.node[(i+1,j+1)]['value']-Call.node[(i+1,j-1)]['value'])/(S.node[(i,j)]['value']*(u-d))
            j=j+2
        i=i-1
        
    return Strat_Call

# %%
def compute_European_Put_strategy(K):

    Put = nx.Graph()
    Put = compute_European_Put_prices(float(K))

    S = nx.Graph()
    S = graph_stock()
    
    Strat_Put = nx.Graph()
    
    for i in range(0,T):
            j=-i+1
            while (j<i+2):
                Strat_Put.add_edge((i,j),(i+1,j+1))
                Strat_Put.add_edge((i,j),(i+1,j-1))
                j=j+2
    
    for n in S.nodes():
        if n[0]==T:
            Strat_Put.node[n]['value'] = 0.0    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            Strat_Put.node[(i,j)]['value'] = (Put.node[(i+1,j+1)]['value']-Put.node[(i+1,j-1)]['value'])/(S.node[(i,j)]['value']*(u-d))
            j=j+2
        i=i-1
        
    return Strat_Put

# %%
# We plot the trees of the hedging strategies
S = nx.Graph()
S = graph_stock()

price_Put = nx.Graph()

K=0.0

K = input("Enter the value of the strike K : ")

Strat_Call = compute_European_Call_strategy(float(K))

Strat_Put = compute_European_Put_strategy(float(K))

plot_tree(S)
plot_tree(Strat_Call)
plot_tree(Strat_Put)
# Out:
# Enter the value of the strike K : 150

# %%
def compute_European_Call_optimal_Wealth(K):

    Call = nx.Graph()
    Call = compute_European_Call_prices(float(K))

    S = nx.Graph()
    S = graph_stock()
    
    Strat_Call = nx.Graph()
    Strat_Call = compute_European_Call_strategy(float(K))
    
    Wealth = nx.Graph()
    
    #Initialization of the tree wealth
    Wealth = Call 
    
    for i in range(0,T):
        j=-i+1
        while (j<i+2):
            Wealth.add_edge((i,j),(i+1,j+1))
            Wealth.node[(i+1,j+1)]['value'] = Strat_Call.node[(i,j)]['value']*S.node[(i+1,j+1)]['value'] + (Wealth.node[(i,j)]['value'] - Strat_Call.node[(i,j)]['value']*S.node[(i,j)]['value'])*(1+r) 

            Wealth.add_edge((i,j),(i+1,j-1))
            Wealth.node[(i+1,j-1)]['value'] = Strat_Call.node[(i,j)]['value']*S.node[(i+1,j-1)]['value'] + (Wealth.node[(i,j)]['value'] - Strat_Call.node[(i,j)]['value']*S.node[(i,j)]['value'])*(1+r) 
            j=j+2
        
    return Wealth

# %%
def compute_European_Put_optimal_Wealth(K):

    Put = nx.Graph()
    Put = compute_European_Put_prices(float(K))

    S = nx.Graph()
    S = graph_stock()
    
    Strat_Put = nx.Graph()
    Strat_Put = compute_European_Put_strategy(float(K))
    
    Wealth = nx.Graph()
    
    #Initialization of the tree wealth
    Wealth = Put 
    
    for i in range(0,T):
        j=-i+1
        while (j<i+2):
            Wealth.add_edge((i,j),(i+1,j+1))
            Wealth.node[(i+1,j+1)]['value'] = Strat_Put.node[(i,j)]['value']*S.node[(i+1,j+1)]['value'] + (Wealth.node[(i,j)]['value'] - Strat_Put.node[(i,j)]['value']*S.node[(i,j)]['value'])*(1+r) 

            Wealth.add_edge((i,j),(i+1,j-1))
            Wealth.node[(i+1,j-1)]['value'] = Strat_Put.node[(i,j)]['value']*S.node[(i+1,j-1)]['value'] + (Wealth.node[(i,j)]['value'] - Strat_Put.node[(i,j)]['value']*S.node[(i,j)]['value'])*(1+r) 
            j=j+2
        
    return Wealth

# %%
# We plot the trees of the wealths associated to the hedging strategies of the Call and the Put
price_Put = nx.Graph()

S = nx.Graph()
S = graph_stock()

K=0.0

K = input("Enter the value of the strike K : ")

Wealth_Call = compute_European_Call_optimal_Wealth(float(K))

Wealth_Put = compute_European_Put_optimal_Wealth(float(K))

plot_tree(S)
plot_tree(Wealth_Call)
plot_tree(Wealth_Put)
# Out:
# Enter the value of the strike K : 150

# %% [markdown]
# ##### 6) We now deal with the case of American Options

# %% [markdown]
# We admit that the price at a given time $t$ of an American Option with respect to the family of discounted payoffs $(\tilde G_t:=(1+r)^{-t} g_t^{Europ}(S_t))_t$ is given by:
# $$ \nu_t = \max\left(\tilde G_t,\mathbb{E}^{\mathbb{P}^\ast}[\nu_{t+1}\vert \mathcal{F}_t]\right), \quad \nu_T:=\tilde G_T. $$

# %% [markdown]
# Deduce that at any time $t$, $\nu_t = f_t^{Amer}(S_t)$ with
# $$ f_t^{Amer}(x):= \max\left((1+r)^{-t} g_t^{Europ}(x),f_{t+1}^{Amer}(x u) p^\ast + f_{t+1}^{Amer}(x d) (1-p^\ast)\right), \quad f_T^{Amer}(x):=g_T^{Europ}(x).$$

# %% [markdown]
# Write a code to compute the graph of an American Call Option and compare it with the price of the European Call Option

# %%
def compute_American_Call_Snell(K):
    
    Snell = nx.Graph()
    
    S = nx.Graph()
    
    S = graph_stock()
    
    for i in range(0,T):
        j=-i+1
        while (j<i+2):
            Snell.add_edge((i,j),(i+1,j+1))
            Snell.add_edge((i,j),(i+1,j-1))
            j=j+2
            
    for n in S.nodes():
        if n[0]==T:
            Snell.node[n]['value'] = European_call(S.node[n]['value'],float(K))*(1.0+r)**(-T) 
    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            temp = Snell.node[(i+1,j+1)]['value']*p_star + Snell.node[(i+1,j-1)]['value']*(1.0-p_star)
            Snell.node[(i,j)]['value'] = np.maximum(European_call(S.node[(i,j)]['value'],float(K))*(1.0+r)**(-i),temp)
            j=j+2
        i=i-1
        
    return Snell

# %%
S = nx.Graph()
S = graph_stock()

Snell_American_Call = nx.Graph()

price_European_Call = nx.Graph()

K=0.0

K = input("Enter the value of the strike K : ")

price_European_Call = compute_European_Call_prices(float(K))

Snell_American_Call = compute_American_Call_Snell(float(K))

plot_tree(S)
plot_tree(price_European_Call)
plot_tree(Snell_American_Call)
# Out:
# Enter the value of the strike K : 150

# %% [markdown]
# American Put Option

# %%
def compute_American_Put_Snell(K):
    
    Snell = nx.Graph()
    
    S = nx.Graph()
    
    S = graph_stock()
    
    for i in range(0,T):
        j=-i+1
        while (j<i+2):
            Snell.add_edge((i,j),(i+1,j+1))
            Snell.add_edge((i,j),(i+1,j-1))
            j=j+2
            
    for n in S.nodes():
        if n[0]==T:
            Snell.node[n]['value'] = European_call(float(K),S.node[n]['value'])*(1.0+r)**(-T) 
    
    i=T-1
    while i>=0:
        j=-i+1
        while j<i+2:
            temp = Snell.node[(i+1,j+1)]['value']*p_star + Snell.node[(i+1,j-1)]['value']*(1.0-p_star)
            Snell.node[(i,j)]['value'] = np.maximum(European_call(float(K),S.node[(i,j)]['value'])*(1.0+r)**(-i),temp)
            j=j+2
        i=i-1
        
    return Snell

# %%
S = nx.Graph()
S = graph_stock()

Snell_American_Put = nx.Graph()

price_European_Put = nx.Graph()

K=0.0

K = input("Enter the value of the strike K : ")

price_European_Put = compute_European_Put_prices(float(K))

Snell_American_Put = compute_American_Put_Snell(float(K))

plot_tree(S)
plot_tree(price_European_Put)
plot_tree(Snell_American_Put)
# Out:
# Enter the value of the strike K : 150
